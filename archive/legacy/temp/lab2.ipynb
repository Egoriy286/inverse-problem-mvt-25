# %%
def u0(x_val):
    return np.sin(np.pi * x_val)


def mu1(t_val):
    return 0.0


def mu2(t_val):
    return 0.0


def p_true(t_val):
    return np.sin(t_val) + 1.0

# %%
import numpy as np; import matplotlib.pyplot as plt;
L=1; T=1; J=100; N=100; mu1=0; mu2=0
tau=T/J; h=L/N; r=2*h**2/tau
y=np.zeros((J+1, N+1)); x=np.linspace(0, L, N+1); t=np.linspace(0, T, J+1)
y[0,:]=np.sin(np.pi * x); v_e = np.sin(t)
for j in range(J):
    A=1.; B=-r-2.; C=1.
    ksi = np.zeros(N+1); eta =np.zeros(N+1)
    ksi[0] = mu1; eta[0]=0
    for i in range(1, N+1):
        ksi[i+1]= -C/(A*ksi[i]+B)
        eta[i+1]= (r*y[j-1][i]-y[j-1][i+1]+2*y[j-1][i]-y[j-1][i]+v_e[j]*2*h*(y[j-1][i] - y[j-1][i-1]))
    y[j][N]=mu2
    for i in range(0, N+1, -1): y[j][i+1]=ksi*y[j-1][i+1]+eta[i+1]
